# %%
import pandas as pd

# %%
data = [1,2,3,4,5]
series = pd.Series(data)
series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
print(type(series))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data2 = {'a':1,'b':2,'c':3}
series2 = pd.Series(data2)
print(series2)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = [10,20,30]
index = ['a','b','c']
pd.Series(data,index = index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
data = {
    'Name':['Krish','John','Darpan'],
    'Age':[25,20,30],
    'City':['Bangalore','New York','Kathmandu']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#      Name  Age       City
# 0   Krish   25  Bangalore
# 1    John   20   New York
# 2  Darpan   30  Kathmandu

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data = [
    {'Name':"Darpan",'Age':20,'City':"Kathmandu"},
    {'Name':"Mahesh",'Age':20,'City':"Pokhara"},
    {'Name':"Kushal",'Age':20,'City':"Butwal"}
]
df = pd.DataFrame(data)

# %%
print(type(df['Name']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.loc[0]
# Out:
# Name       Darpan
# Age            20
# City    Kathmandu
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# Name       Darpan
# Age            20
# City    Kathmandu
# Name: 0, dtype: object

# %%
df.loc[0][0]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7248\2527876973.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[0][0]
# 'Darpan'

# %%
df.iloc[0][0]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7248\2900375399.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][0]
# 'Darpan'

# %%
df.iloc[0][1]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7248\2309508539.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][1]
# 20

# %%
df
# Out:
#      Name  Age       City
# 0  Darpan   20  Kathmandu
# 1  Mahesh   20    Pokhara
# 2  Kushal   20     Butwal

# %%
df.at[2,'Age']
# Out:
# 20

# %%
df.at[2,'City']
# Out:
# 'Butwal'

# %%
df.iat[2,2]
# Out:
# 'Butwal'

# %%
df["Salary"] = [10000,20000,30000]
df
# Out:
#      Name  Age       City  Salary
# 0  Darpan   20  Kathmandu   10000
# 1  Mahesh   20    Pokhara   20000
# 2  Kushal   20     Butwal   30000

# %%
df.drop('Salary',axis=1)
# Out:
#      Name  Age       City
# 0  Darpan   20  Kathmandu
# 1  Mahesh   20    Pokhara
# 2  Kushal   20     Butwal

# %%
df
# Out:
#      Name  Age       City  Salary
# 0  Darpan   20  Kathmandu   10000
# 1  Mahesh   20    Pokhara   20000
# 2  Kushal   20     Butwal   30000

# %%
df.drop('Salary')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.drop('Salary')
#
# File c:\Users\Dell\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\Dell\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\Dell\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\Dell\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Salary'] not found in axis"

# %%
df.drop('Salary',axis=1,inplace=True)

# %%
df
# Out:
#      Name  Age       City
# 0  Darpan   20  Kathmandu
# 1  Mahesh   20    Pokhara
# 2  Kushal   20     Butwal

# %%
df['Age'] = df['Age']+1
df
# Out:
#      Name  Age       City
# 0  Darpan   21  Kathmandu
# 1  Mahesh   21    Pokhara
# 2  Kushal   21     Butwal

# %%
df.drop(0)
# Out:
#      Name  Age     City
# 1  Mahesh   21  Pokhara
# 2  Kushal   21   Butwal

# %%
df
# Out:
#      Name  Age       City
# 0  Darpan   21  Kathmandu
# 1  Mahesh   21    Pokhara
# 2  Kushal   21     Butwal

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#      Name  Age     City
# 1  Mahesh   21  Pokhara
# 2  Kushal   21   Butwal

# %%
df.dtypes
# Out:
# Name    object
# Age      int64
# City    object
# dtype: object

# %%
df.describe()
# Out:
#         Age
# count   2.0
# mean   21.0
# std     0.0
# min    21.0
# 25%    21.0
# 50%    21.0
# 75%    21.0
# max    21.0
